# %%
import polars as pl
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# %%
df = pl.read_ods('projecoes_2024_tab1_idade_simples.ods')

# %%
df.head(10)
# Out:
# shape: (10, 76)
# ┌───────┬───────┬──────┬───────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ IDADE ┆ SEXO  ┆ CÓD. ┆ SIGLA ┆ … ┆ 2067    ┆ 2068    ┆ 2069    ┆ 2070    │
# │ ---   ┆ ---   ┆ ---  ┆ ---   ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ i64   ┆ str   ┆ i64  ┆ str   ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞═══════╪═══════╪══════╪═══════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 0     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1521584 ┆ 1509151 ┆ 1497237 ┆ 1485716 │
# │ 1     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1534002 ┆ 1520805 ┆ 1508394 ┆ 1496496 │
# │ 2     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1547800 ┆ 1533609 ┆ 1520415 ┆ 1508015 │
# │ 3     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1562761 ┆ 1547399 ┆ 1533216 ┆ 1520035 │
# │ 4     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1578625 ┆ 1562356 ┆ 1547006 ┆ 1532831 │
# │ 5     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1595110 ┆ 1578328 ┆ 1562067 ┆ 1546730 │
# │ 6     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1612838 ┆ 1594921 ┆ 1578149 ┆ 1561890 │
# │ 7     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1632320 ┆ 1612649 ┆ 1594737 ┆ 1577972 │
# │ 8     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1653352 ┆ 1632128 ┆ 1612466 ┆ 1594559 │
# │ 9     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1675016 ┆ 1653160 ┆ 1631941 ┆ 1612282 │
# └───────┴───────┴──────┴───────┴───┴─────────┴─────────┴─────────┴─────────┘

# %%
df['LOCAL'].unique().to_list()
# Out:
# ['Paraná',
#  'Acre',
#  'Distrito Federal',
#  'Rondônia',
#  'Rio Grande do Norte',
#  'Mato Grosso',
#  'Amazonas',
#  'Pernambuco',
#  'Pará',
#  'Santa Catarina',
#  'Rio Grande do Sul',
#  'Ceará',
#  'Brasil',
#  'Sergipe',
#  'Amapá',
#  'Nordeste',
#  'Tocantins',
#  'Norte',
#  'Centro-Oeste',
#  'Rio de Janeiro',
#  'Goiás',
#  'Alagoas',
#  'Roraima',
#  'Mato Grosso do Sul',
#  'Sudeste',
#  'Minas Gerais',
#  'Espírito Santo',
#  'Maranhão',
#  'Paraíba',
#  'Piauí',
#  'São Paulo',
#  'Sul',
#  'Bahia']

# %%
df['SEXO'].unique()
# Out:
# shape: (3,)
# Series: 'SEXO' [str]
# [
# 	"Homens"
# 	"Mulheres"
# 	"Ambos"
# ]

# %%
df.head()
# Out:
# shape: (5, 76)
# ┌───────┬───────┬──────┬───────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ IDADE ┆ SEXO  ┆ CÓD. ┆ SIGLA ┆ … ┆ 2067    ┆ 2068    ┆ 2069    ┆ 2070    │
# │ ---   ┆ ---   ┆ ---  ┆ ---   ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ i64   ┆ str   ┆ i64  ┆ str   ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞═══════╪═══════╪══════╪═══════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 0     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1521584 ┆ 1509151 ┆ 1497237 ┆ 1485716 │
# │ 1     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1534002 ┆ 1520805 ┆ 1508394 ┆ 1496496 │
# │ 2     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1547800 ┆ 1533609 ┆ 1520415 ┆ 1508015 │
# │ 3     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1562761 ┆ 1547399 ┆ 1533216 ┆ 1520035 │
# │ 4     ┆ Ambos ┆ 0    ┆ BR    ┆ … ┆ 1578625 ┆ 1562356 ┆ 1547006 ┆ 1532831 │
# └───────┴───────┴──────┴───────┴───┴─────────┴─────────┴─────────┴─────────┘

# %%
df_long = df.unpivot(
    on=[str(ano) for ano in range(2000, 2071)],
    index=['IDADE', 'SEXO', 'LOCAL'],
    variable_name='ANO',
    value_name='POPULACAO'
)

# %%
df_long
# Out:
# shape: (639_639, 5)
# ┌───────┬──────────┬──────────────────┬──────┬───────────┐
# │ IDADE ┆ SEXO     ┆ LOCAL            ┆ ANO  ┆ POPULACAO │
# │ ---   ┆ ---      ┆ ---              ┆ ---  ┆ ---       │
# │ i64   ┆ str      ┆ str              ┆ str  ┆ i64       │
# ╞═══════╪══════════╪══════════════════╪══════╪═══════════╡
# │ 0     ┆ Ambos    ┆ Brasil           ┆ 2000 ┆ 3423475   │
# │ 1     ┆ Ambos    ┆ Brasil           ┆ 2000 ┆ 3450022   │
# │ 2     ┆ Ambos    ┆ Brasil           ┆ 2000 ┆ 3461038   │
# │ 3     ┆ Ambos    ┆ Brasil           ┆ 2000 ┆ 3469109   │
# │ 4     ┆ Ambos    ┆ Brasil           ┆ 2000 ┆ 3477903   │
# │ …     ┆ …        ┆ …                ┆ …    ┆ …         │
# │ 86    ┆ Mulheres ┆ Distrito Federal ┆ 2070 ┆ 15492     │
# │ 87    ┆ Mulheres ┆ Distrito Federal ┆ 2070 ┆ 14535     │
# │ 88    ┆ Mulheres ┆ Distrito Federal ┆ 2070 ┆ 13618     │
# │ 89    ┆ Mulheres ┆ Distrito Federal ┆ 2070 ┆ 12708     │
# │ 90    ┆ Mulheres ┆ Distrito Federal ┆ 2070 ┆ 66871     │
# └───────┴──────────┴──────────────────┴──────┴───────────┘

# %%
df_br_ambos_homens_mulheres = df_long.filter(
    pl.col('LOCAL') == 'Brasil'
).group_by(
    ['SEXO', 'ANO']
).agg(
    pl.col('POPULACAO').sum()
).with_columns(
    pl.col('ANO').cast(pl.Int16)
).sort(['ANO', 'SEXO'])

# %%
df_br_ambos_homens_mulheres
# Out:
# shape: (213, 3)
# ┌──────────┬──────┬───────────┐
# │ SEXO     ┆ ANO  ┆ POPULACAO │
# │ ---      ┆ ---  ┆ ---       │
# │ str      ┆ i16  ┆ i64       │
# ╞══════════╪══════╪═══════════╡
# │ Ambos    ┆ 2000 ┆ 174695935 │
# │ Homens   ┆ 2000 ┆ 85720706  │
# │ Mulheres ┆ 2000 ┆ 88975229  │
# │ Ambos    ┆ 2001 ┆ 177003743 │
# │ Homens   ┆ 2001 ┆ 86821427  │
# │ …        ┆ …    ┆ …         │
# │ Homens   ┆ 2069 ┆ 97739608  │
# │ Mulheres ┆ 2069 ┆ 102833767 │
# │ Ambos    ┆ 2070 ┆ 199228708 │
# │ Homens   ┆ 2070 ┆ 97118626  │
# │ Mulheres ┆ 2070 ┆ 102110082 │
# └──────────┴──────┴───────────┘

# %%
df_br_ambos = df_br_ambos_homens_mulheres.to_pandas().query('SEXO == "Ambos"').reset_index(drop=True)

# %%
df_br_ambos
# Out:
#      SEXO   ANO  POPULACAO
# 0   Ambos  2000  174695935
# 1   Ambos  2001  177003743
# 2   Ambos  2002  179228254
# 3   Ambos  2003  181377654
# 4   Ambos  2004  183469593
# ..    ...   ...        ...
# 66  Ambos  2066  204415091
# 67  Ambos  2067  203168549
# 68  Ambos  2068  201887385
# 69  Ambos  2069  200573375
# 70  Ambos  2070  199228708
#
# [71 rows x 3 columns]

# %%
df_br_ambos.dtypes
# Out:
# SEXO           str
# ANO          int16
# POPULACAO    int64
# dtype: object

# %%
df_br_homens_mulheres = df_br_ambos_homens_mulheres.to_pandas().query('SEXO != "Ambos"').reset_index(drop=True)

# %%
df_br_homens_mulheres
# Out:
#          SEXO   ANO  POPULACAO
# 0      Homens  2000   85720706
# 1    Mulheres  2000   88975229
# 2      Homens  2001   86821427
# 3    Mulheres  2001   90182316
# 4      Homens  2002   87882321
# ..        ...   ...        ...
# 137  Mulheres  2068  103540008
# 138    Homens  2069   97739608
# 139  Mulheres  2069  102833767
# 140    Homens  2070   97118626
# 141  Mulheres  2070  102110082
#
# [142 rows x 3 columns]

# %%
fig = plt.figure(figsize=(12, 8), dpi=300)

gs = GridSpec(2, 2, figure=fig)

ax0 = fig.add_subplot(gs[0, :])
ax1 = fig.add_subplot(gs[1, :])

ax0.plot(
    df_br_ambos['ANO'],
    df_br_ambos['POPULACAO'],
    marker='o'
)

cores = plt.get_cmap('Dark2').colors
marcadores = ['o', '>']

for (sexo, grupo), cor, marcador in zip(df_br_homens_mulheres.groupby('SEXO'), cores, marcadores):
    ax1.plot(
        grupo['ANO'],
        grupo['POPULACAO'],
        color=cor,
        marker=marcador,
        label=sexo
    )

anos = list(range(2000, 2071, 5))

for ax in [ax0, ax1]:
    ax.set_xticks(anos)
    ax.tick_params('x', rotation=45)
    ax.set_ylabel('População Projetada')
    ax.set_xlabel('Ano')
    ax.grid(color='grey', linestyle='--', alpha=0.5)
    ax.spines[['top', 'right']].set_visible(False)

ax1.legend(loc='best')

plt.tight_layout()
fig.savefig('projecao_populacao_ibge_ambos_homens_mulheres_2000_2070.png', dpi=300, bbox_inches='tight')
plt.show()
