# %%
import pandas as pd

# %%
import pandas as pd

# Criando os dados baseados na sua imagem
data = {
    'Estabelecimento': [
        'AMAZON', 'MERCADO LIVRE', 'KALUNGA', 'VIDAECOR', 'MAGALU', 'AMAZON', 
        'AMAZON', 'Quantumnotes', 'TEMU', 'MERCADO LIVRE', 'MAGALU', 'Pracasaber', 
        'MERCADO LIVRE', 'AMAZON', 'Rdsaude', 'AMAZON', 'GOOGLE', 'QCONCURSOS', 
        'Gimtoni', 'Netshoes', 'Leituramidway', 'AMERICANAS', 'Leituramidway', 'VIVO'
    ],
    'Valor': [
        '36,69', '33,62', '43,3', '21,96', '170,9', '37,2', '86,37', '42,17', 
        '35,05', '87,23', '53,86', '43,93', '138,64', '41,75', '50,32', '79,57', 
        '4,5', '34,9', '29,9', '111,58', '39,95', '11,99', '22,85', '47,27'
    ],
    'Categoria': [
        'MÃE', 'MÃE', 'PAI', 'MÃE', 'MÃE', 'MÃE', 'MÃE', 'MÃE', 'MÃE', 'MÃE', 
        'MÃE', 'MÃE', 'MÃE', 'MÃE', 'MÃE', 'MÃE', 'EU', 'EU', 'PAI', 'PAI', 
        'EU', 'EU', 'EU', 'PAI'
    ]
}

# Criando o DataFrame
df = pd.DataFrame(data)

# Tratando a coluna 'Valor': substitui vírgula por ponto e converte para float
df['Valor'] = df['Valor'].str.replace(',', '.').astype(float)

# Exibindo o resultado
print(df)
# Out:
#    Estabelecimento   Valor Categoria
# 0           AMAZON   36.69       MÃE
# 1    MERCADO LIVRE   33.62       MÃE
# 2          KALUNGA   43.30       PAI
# 3         VIDAECOR   21.96       MÃE
# 4           MAGALU  170.90       MÃE
# 5           AMAZON   37.20       MÃE
# 6           AMAZON   86.37       MÃE
# 7     Quantumnotes   42.17       MÃE
# 8             TEMU   35.05       MÃE
# 9    MERCADO LIVRE   87.23       MÃE
# 10          MAGALU   53.86       MÃE
# 11      Pracasaber   43.93       MÃE
# 12   MERCADO LIVRE  138.64       MÃE
# 13          AMAZON   41.75       MÃE
# 14         Rdsaude   50.32       MÃE
# 15          AMAZON   79.57       MÃE
# 16          GOOGLE    4.50        EU
# 17      QCONCURSOS   34.90        EU
# 18         Gimtoni   29.90       PAI
# 19        Netshoes  111.58       PAI
# 20   Leituramidway   39.95        EU
# 21      AMERICANAS   11.99        EU
# 22   Leituramidway   22.85        EU
# 23            VIVO   47.27       PAI

# %%
df.groupby('Categoria').agg({
    'Valor': 'sum'
})
# Out:
#             Valor
# Categoria
# EU         114.19
# MÃE        959.26
# PAI        232.05
